# %% [markdown]
# # Statistics in Python Assignment

# %% [markdown]
# ## The pandas data-frame

# %% [markdown]
# ### Imports

# %%
import numpy as np

# %%
import statsmodels.api as sm

# %%
import statsmodels.formula.api as smf

# %%
from statsmodels.formula.api import ols

# %%
from statsmodels.stats.anova import anova_lm

# %%
import pandas as pandas
pandas.__version__
# Out:
# '1.4.4'

# %%
import pandas.plotting as plotting

# %%
from pandas.plotting import scatter_matrix

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import scipy as scipy

# %%
from scipy import stats

# %%
import urllib

# %%
from urllib.request import urlretrieve

# %%
import os

# %%
import seaborn

# %% [markdown]
# ### The pandas data-frame¶

# %% [markdown]
# ### Creating dataframes: reading data files or converting arrays

# %% [markdown]
# #### Reading from a CSV file

# %%
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".") 
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# ...

# %% [markdown]
# #### Creating from arrays and Expose data files as a pandas.DataFrame

# %%
t = np.linspace(-6, 6, 20)

# %%
sin_t = np.sin(t)

# %%
cos_t = np.cos(t)

# %%
pandas.DataFrame({'t': t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %% [markdown]
# ## Manipulating data

# %% [markdown]
# ####  Below will show #of rows and columns eg: 40 rows and 8 columns

# %%
data.shape
# Out:
# (40, 8)

# %% [markdown]
# #### Below will show the columns it has

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')

# %% [markdown]
# #### Columns can be addressed by name

# %%
print(data['Gender'])
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %% [markdown]
# #### Simpler selector

# %%
data[data['Gender'] == 'Female']['VIQ'].mean()
# Out:
# 109.45

# %%
data.describe()
# Out:
#        Unnamed: 0        FSIQ         VIQ        PIQ      Weight     Height  \
# count   40.000000   40.000000   40.000000   40.00000   38.000000  39.000000
# mean    20.500000  113.450000  112.350000  111.02500  151.052632  68.525641
# std     11.690452   24.082071   23.616107   22.47105   23.478509   3.994649
# min      1.000000   77.000000   71.000000   72.00000  106.000000  62.000000
# 25%     10.750000   89.750000   90.000000   88.25000  135.250000  66.000000
# 50%     20.500000  116.500000  113.000000  115.00000  146.500000  68.000000
# 75%     30.250000  135.500000  129.750000  128.00000  172.000000  70.500000
# max     40.000000  144.000000  150.000000  150.00000  192.000000  77.000000
#
#           MRI_Count
# count  4.000000e+01
# mean   9.087550e+05
# std    7.228205e+04
# min    7.906190e+05
# 25%    8.559185e+05
# 50%    9.053990e+05
# 75%    9.500780e+05
# max    1.079549e+06

# %% [markdown]
# #### Groupby: splitting a dataframe on values of categorical variables:

# %%
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.mean()))
# Out:
# ('Female', 109.45)
# ('Male', 115.25)

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %% [markdown]
# #### Plotting data

# %%
plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<AxesSubplot:xlabel='Weight', ylabel='Weight'>,
#         <AxesSubplot:xlabel='Height', ylabel='Weight'>,
#         <AxesSubplot:xlabel='MRI_Count', ylabel='Weight'>],
#        [<AxesSubplot:xlabel='Weight', ylabel='Height'>,
#         <AxesSubplot:xlabel='Height', ylabel='Height'>,
#         <AxesSubplot:xlabel='MRI_Count', ylabel='Height'>],
#        [<AxesSubplot:xlabel='Weight', ylabel='MRI_Count'>,
#         <AxesSubplot:xlabel='Height', ylabel='MRI_Count'>,
#         <AxesSubplot:xlabel='MRI_Count', ylabel='MRI_Count'>]],
#       dtype=object)

# %%
plotting.scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<AxesSubplot:xlabel='PIQ', ylabel='PIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='PIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='PIQ'>],
#        [<AxesSubplot:xlabel='PIQ', ylabel='VIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='VIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='VIQ'>],
#        [<AxesSubplot:xlabel='PIQ', ylabel='FSIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='FSIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='FSIQ'>]], dtype=object)

# %% [markdown]
# ### Exercise 1

# %%
#### What is the mean value for VIQ for the full population?
mean_viq = data['VIQ'].mean()
print(mean_viq)

#### How many males/females were included in this study?
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".") 
gender_counts = data['Gender'].value_counts()
print(gender_counts)

#### What is the average value of MRI counts expressed in log units, for males and females?
male_avg = np.mean(data[data['Gender'] == 'Male']['MRI_Count'])
female_avg = np.mean(data[data['Gender'] == 'Female']['MRI_Count'])

print("Average log MRI counts for males:", male_avg)
print("Average log MRI counts for females:", female_avg)
# Out:
# 112.35
# Female    20
# Male      20
# Name: Gender, dtype: int64
# Average log MRI counts for males: 954855.4
# Average log MRI counts for females: 862654.6

# %% [markdown]
# #### Box plots of different columns for each gender (example)

# %%
groupby_gender = data.groupby('Gender')
groupby_gender.boxplot(column=['FSIQ', 'VIQ', 'PIQ'])
# Out:
# Female         AxesSubplot(0.1,0.15;0.363636x0.75)
# Male      AxesSubplot(0.536364,0.15;0.363636x0.75)
# dtype: object

# %% [markdown]
# #### Scatter matrices for different columns

# %%
pandas.plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<AxesSubplot:xlabel='Weight', ylabel='Weight'>,
#         <AxesSubplot:xlabel='Height', ylabel='Weight'>,
#         <AxesSubplot:xlabel='MRI_Count', ylabel='Weight'>],
#        [<AxesSubplot:xlabel='Weight', ylabel='Height'>,
#         <AxesSubplot:xlabel='Height', ylabel='Height'>,
#         <AxesSubplot:xlabel='MRI_Count', ylabel='Height'>],
#        [<AxesSubplot:xlabel='Weight', ylabel='MRI_Count'>,
#         <AxesSubplot:xlabel='Height', ylabel='MRI_Count'>,
#         <AxesSubplot:xlabel='MRI_Count', ylabel='MRI_Count'>]],
#       dtype=object)

# %%
plotting.scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<AxesSubplot:xlabel='PIQ', ylabel='PIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='PIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='PIQ'>],
#        [<AxesSubplot:xlabel='PIQ', ylabel='VIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='VIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='VIQ'>],
#        [<AxesSubplot:xlabel='PIQ', ylabel='FSIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='FSIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='FSIQ'>]], dtype=object)

# %%
groupby_gender.boxplot = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.mean()))
# Out:
# ('Female', 109.45)
# ('Male', 115.25)

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %%
groupby_gender.count()
# Out:
#         Unnamed: 0  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# Gender
# Female          20    20   20   20      20      20         20
# Male            20    20   20   20      18      19         20

# %% [markdown]
# #### Two populations

# %%
groupby_gender = data.groupby('Gender')
plotting.scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<AxesSubplot:xlabel='PIQ', ylabel='PIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='PIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='PIQ'>],
#        [<AxesSubplot:xlabel='PIQ', ylabel='VIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='VIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='VIQ'>],
#        [<AxesSubplot:xlabel='PIQ', ylabel='FSIQ'>,
#         <AxesSubplot:xlabel='VIQ', ylabel='FSIQ'>,
#         <AxesSubplot:xlabel='FSIQ', ylabel='FSIQ'>]], dtype=object)

# %% [markdown]
# ### Exercise 2

# %%
### Plot the scatter matrix for males only, and for females only.

#### For males



male_data = data[data['Gender'] == 'Male']
plotting.scatter_matrix(male_data[['PIQ', 'VIQ', 'FSIQ']])
plt.suptitle("Scatter Matrix for Males", y=1.05, fontsize=11)
plt.show()

#### For females

female_data = data[data['Gender'] == 'Female']
plotting.scatter_matrix(female_data[['PIQ', 'VIQ', 'FSIQ']])
plt.suptitle("Scatter Matrix for Females", y=1.05, fontsize=11)
plt.show()

# %% [markdown]
# ## 3.1.2. Hypothesis testing: comparing two groups

# %% [markdown]
# ### 3.1.2.1. Student’s t-test: the simplest statistical test

# %% [markdown]
# #### 1-sample t-test: testing the value of a population mean

# %%
stats.ttest_1samp(data['VIQ'], 0)
# Out:
# Ttest_1sampResult(statistic=30.08809997084933, pvalue=1.3289196468727879e-28)

# %% [markdown]
# #### 2-sample t-test: testing for difference across populations

# %%
female_viq = data[data['Gender'] == 'Female']['VIQ']
male_viq = data[data['Gender'] == 'Male']['VIQ']
stats.ttest_ind(female_viq, male_viq)
# Out:
# Ttest_indResult(statistic=-0.7726161723275012, pvalue=0.44452876778583217)

# %% [markdown]
# ### 3.1.2.2. Paired tests: repeated measurements on the same individuals

# %% [markdown]
# ### To test if FISQ and PIQ are significantly different. We can use a 2 sample test:

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# Ttest_indResult(statistic=0.465637596380964, pvalue=0.6427725009414841)

# %%
data = pandas.read_csv('brain_size.csv', sep=';', na_values='.')
plt.figure(figsize=(4, 3))
data.boxplot(column=['FSIQ', 'PIQ'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### The variance due to inter-subject variability is confounding, and can be removed, using a “paired test”, or “repeated measures test”:

# %%
stats.ttest_rel(data['FSIQ'], data['PIQ'])
# Out:
# Ttest_relResult(statistic=1.7842019405859857, pvalue=0.08217263818364236)

# %% [markdown]
# #### This is equivalent to a 1-sample test on the difference:

# %%
stats.ttest_1samp(data['FSIQ'] - data['PIQ'], 0)
# Out:
# Ttest_1sampResult(statistic=1.7842019405859857, pvalue=0.08217263818364236)

# %%
plt.figure(figsize=(4, 3))
plt.boxplot(data['FSIQ'] - data['PIQ'])
plt.xticks((1, ), ('FSIQ - PIQ', ))
# Out:
# ([<matplotlib.axis.XTick at 0x2048db2b280>], [Text(1, 0, 'FSIQ - PIQ')])

# %%
stats.wilcoxon(data['FSIQ'], data['PIQ'])
# Out:
# C:\Users\thaan\anaconda3\lib\site-packages\scipy\stats\_morestats.py:3255: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# WilcoxonResult(statistic=274.5, pvalue=0.10659492713506856)

# %%
scipy.stats.mannwhitneyu(data['FSIQ'], data['PIQ'])
# Out:
# MannwhitneyuResult(statistic=905.0, pvalue=0.3143162646412675)

# %% [markdown]
# ### Exercise 3

# %%
#### Test the difference between weights in males and females.

data = pandas.read_csv('brain_size.csv', sep=';', na_values=".") 
data = data.dropna(subset=['Weight'])

male_weights = data[data['Gender'] == 'Male']['Weight']
female_weights = data[data['Gender'] == 'Female']['Weight']

t_stat, p_value = stats.ttest_ind(male_weights, female_weights)

print("T-Statistic:", t_stat)
print("P-Value:", p_value)

#### Use non parametric statistics to test the difference between VIQ in males and females
female_VIQ = data[data['Gender'] == 'Female']['VIQ']
male_VIQ = data[data['Gender'] == 'Male']['VIQ']

scipy.stats.mannwhitneyu(data['VIQ'], data['VIQ'])
# Out:
# T-Statistic: 4.870950921940696
# P-Value: 2.227293018362118e-05
# MannwhitneyuResult(statistic=722.0, pvalue=1.0)

# %% [markdown]
# ##### Conclusion: we find that the data does not support the hypothesis that males and females have different VIQ.

# %% [markdown]
# ## 3.1.3. Linear models, multiple factors, and analysis of variance

# %% [markdown]
# ### 3.1.3.1. “formulas” to specify statistical models in Python

# %%
x = np.linspace(-5, 5, 20)
np.random.seed(1)

# %% [markdown]
# #### normal distributed noise

# %%
y = -5 + 3*x + 4 * np.random.normal(size=x.shape)

# %% [markdown]
# #### Create a data frame containing all the relevant variables

# %%
data = pandas.DataFrame({'x': x, 'y': y})

# %%
model = ols("y ~ x", data).fit()

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.03
# Date:                Mon, 17 Jul 2023   Prob (F-statistic):           8.56e-08
# Time:                        00:40:28   Log-Likelihood:                -57.988
# No. Observations:                  20   AIC:                             120.0
# Df Residuals:                      18   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5335      1.036     -5.342      0.000      -7.710      -3.357
# ...

# %% [markdown]
# ### Exercise 4

# %%
#### Retrieve the estimated parameters from the model above.

estimated_params = model.params
print(model.params)

p_values = model.pvalues
print(model.pvalues)

conf_intervals = model.conf_int()
print(model.conf_int())
# Out:
# Intercept   -5.533459
# x            2.936888
# dtype: float64
# Intercept    4.459607e-05
# x            8.560649e-08
# dtype: float64
#                   0         1
# Intercept -7.709853 -3.357065
# x          2.219763  3.654014

# %% [markdown]
# ### Categorical variables: comparing groups or multiple categories

# %%
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")

# %% [markdown]
# <span style="color: blue;">We can write a comparison between IQ of male and female using a linear model:.</span>

# %%
model = ols("VIQ ~ Gender + 1", data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    VIQ   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Mon, 17 Jul 2023   Prob (F-statistic):              0.445
# Time:                        00:43:13   Log-Likelihood:                -182.42
# No. Observations:                  40   AIC:                             368.8
# Df Residuals:                      38   BIC:                             372.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        109.4500      5.308     20.619      0.000      98.704     120.196
# ...

# %% [markdown]
# ### Link to t-tests between different FSIQ and PIQ

# %% [markdown]
# <span style="color: green;">**To compare different types of IQ, we need to create a “long-form” table, listing IQs, where the type of IQ is indicated by a categorical variable:**</span>

# %%
data_fisq = pandas.DataFrame({'iq': data['FSIQ'], 'type': 'fsiq'})
data_piq = pandas.DataFrame({'iq': data['PIQ'], 'type': 'piq'})
data_long = pandas.concat((data_fisq, data_piq))
print(data_long)
# Out:
#      iq  type
# 0   133  fsiq
# 1   140  fsiq
# 2   139  fsiq
# 3   133  fsiq
# 4   137  fsiq
# ..  ...   ...
# 35  128   piq
# 36  124   piq
# 37   94   piq
# 38   74   piq
# 39   89   piq
#
# [80 rows x 2 columns]

# %%
model = ols("iq ~ type", data_long).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     iq   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2168
# Date:                Mon, 17 Jul 2023   Prob (F-statistic):              0.643
# Time:                        00:44:17   Log-Likelihood:                -364.35
# No. Observations:                  80   AIC:                             732.7
# Df Residuals:                      78   BIC:                             737.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     113.4500      3.683     30.807      0.000     106.119     120.781
# ...

# %% [markdown]
# <span style="color: green;">**Retrieve the same values for t-test and corresponding p-values for the effect of the type of iq than the previous t-test:**</span>

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# Ttest_indResult(statistic=0.465637596380964, pvalue=0.6427725009414841)

# %% [markdown]
# ## 3.1.3.2. Multiple Regression: including multiple factors

# %% [markdown]
# ##### A linear model explaining a variable z (the dependent variable) can be seen in 3D as fitting a plane to a cloud of (x, y, z) points.

# %%
data = pandas.read_csv('iris.csv')
print(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width       name
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
model = ols('sepal_width ~ name + petal_length', data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            sepal_width   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     44.63
# Date:                Mon, 17 Jul 2023   Prob (F-statistic):           1.58e-20
# Time:                        00:45:38   Log-Likelihood:                -38.185
# No. Observations:                 150   AIC:                             84.37
# Df Residuals:                     146   BIC:                             96.41
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.9813      0.099     29.989      0.000       2.785       3.178
# ...

# %%
cluster_colors = {'setosa': 'purple', 'versicolor': 'green', 'virginica': 'yellow'}
colors = [cluster_colors[label] for label in data['name']]
scatter_matrix_plot =plotting.scatter_matrix(data[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']],color=colors)
title_text = 'Blue: Setosa, Green: Versicolor, Red: Virginica'
plt.suptitle(title_text, fontsize=11)
# Out:
# Text(0.5, 0.98, 'Blue: Setosa, Green: Versicolor, Red: Virginica')

# %% [markdown]
# ### 3.1.3.3. Post-hoc hypothesis testing: analysis of variance (ANOVA)

# %% [markdown]
# #### To test if the petal length is different between versicolor and virginica, after removing the effect of sepal width, we want to test "name[T.versicolor] - name[T.virginica]", with an F-test:

# %%
print(model.f_test([0, 1, -1, 0]))
# Out:
# <F test: F=3.245335346574282, p=0.07369058781700653, df_denom=146, df_num=1>

# %% [markdown]
# ##### Since, the p value is greater than 0.05, null hypothesis is not rejected. Therefore, there is no significance difference in the petal length between versicolor and virginica.

# %% [markdown]
# ### Exercise 5

# %%
#### Going back to the brain size + IQ data, test if the VIQ of male and female are different after removing the effect of brain size, height and weight.

data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")

df = data[['VIQ', 'Gender', 'MRI_Count', 'Height', 'Weight']]
df = df.dropna()
df_encoded = pandas.get_dummies(df, columns=['Gender'], drop_first=True)
model = sm.OLS(df_encoded['VIQ'], sm.add_constant(df_encoded[['MRI_Count', 'Height', 'Weight']]))
result = model.fit()

ssr = result.ssr
df_regression = result.df_model
msr = ssr / df_regression

sse = result.ssr + result.centered_tss
df_residual = result.df_resid
mse = sse / df_residual

f_statistic = msr / mse
p_value = 1 - stats.f.cdf(f_statistic, df_regression, df_residual)

anova_table = pandas.DataFrame({'df_regression': [df_regression],
                            'ssr': [ssr],
                            'msr': [msr],
                            'df_residual': [df_residual],
                            'sse': [sse],
                            'mse': [mse],
                            'f_statistic': [f_statistic],
                            'p_value': [p_value]})

anova_table.index = ['ANOVA']
anova_table.index.name = 'Source'

print(anova_table)

##### Since, the p value is greater than 0.05, null hypothesis is not rejected. Therefore, there is no significance difference in the VIQ of male and female
# Out:
#         df_regression           ssr        msr  df_residual           sse  \
# Source
# ANOVA             3.0  15011.413199  5003.8044         34.0  34481.755305
#
#                 mse  f_statistic  p_value
# Source
# ANOVA   1014.169274     4.933895  0.00596

# %% [markdown]
# ## 3.1.4. More visualization: seaborn for statistical exploration

# %% [markdown]
# #### 3.1.6.7. Visualizing factors influencing wages

# %% [markdown]
# ##### Download the file if it is not present

# %%
import pandas as pd
import os
from urllib.request import urlretrieve

if not os.path.exists('wages.txt'):
    # Download the file if it is not present
    urlretrieve('http://lib.stat.cmu.edu/datasets/CPS_85_Wages', 'wages.txt')

# %% [markdown]
# ##### Give names to the columns

# %%
names = [
    'EDUCATION: Number of years of education',
    'SOUTH: 1=Person lives in South, 0=Person lives elsewhere',
    'SEX: 1=Female, 0=Male',
    'EXPERIENCE: Number of years of work experience',
    'UNION: 1=Union member, 0=Not union member',
    'WAGE: Wage (dollars per hour)',
    'AGE: years',
    'RACE: 1=Other, 2=Hispanic, 3=White',
    'OCCUPATION: 1=Management, 2=Sales, 3=Clerical, 4=Service, 5=Professional, 6=Other',
    'SECTOR: 0=Other, 1=Manufacturing, 2=Construction',
    'MARR: 0=Unmarried,  1=Married',
]

# %%
short_names = [n.split(':')[0] for n in names]

# %%
data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, sep=None, header=None, engine='python')

# %%
data.columns = short_names

# %% [markdown]
# ##### Log-transform the wages, because they typically are increased with multiplicative factors

# %%
data['WAGE'] = np.log10(data['WAGE'])

# %% [markdown]
# ### 3.1.4.1. Pairplot: scatter matrices

# %% [markdown]
# #### To display a scatter matrix

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg')

# %% [markdown]
# #### Plot scatter matrices highlighting different aspects
#
# #### Categorical variables can be plotted as the hue:

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='SEX')
plt.suptitle('Effect of gender: 1=Female, 0=Male')
# Out:
# Text(0.5, 0.98, 'Effect of gender: 1=Female, 0=Male')

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='RACE')
plt.suptitle('Effect of race: 1=Other, 2=Hispanic, 3=White')
# Out:
# Text(0.5, 0.98, 'Effect of race: 1=Other, 2=Hispanic, 3=White')

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                      kind='reg', hue='UNION')
plt.suptitle('Effect of union: 1=Union member, 0=Not union member')
# Out:
# Text(0.5, 0.98, 'Effect of union: 1=Union member, 0=Not union member')

# %% [markdown]
# #### Plot a simple regression

# %%
seaborn.lmplot(y='WAGE', x='EDUCATION', data=data)

plt.show()

# %% [markdown]
# #### Look and feel and matplotlib settings

# %%
from matplotlib import pyplot as plt
plt.rcdefaults()

# %% [markdown]
# ### 3.1.4.2. lmplot: plotting a univariate regression

# %% [markdown]
# ##### A regression capturing the relation between one variable and another, eg wage and eduction, can be plotted using seaborn.lmplot():

# %%
seaborn.lmplot(y='WAGE', x='EDUCATION', data=data)

# %%
import pandas as pd
import os
from urllib.request import urlretrieve

if not os.path.exists('wages.txt'):
    # Download the file if it is not present
    urlretrieve('http://lib.stat.cmu.edu/datasets/CPS_85_Wages', 'wages.txt')

# %%
names = [
    'EDUCATION: Number of years of education',
    'SOUTH: 1=Person lives in South, 0=Person lives elsewhere',
    'SEX: 1=Female, 0=Male',
    'EXPERIENCE: Number of years of work experience',
    'UNION: 1=Union member, 0=Not union member',
    'WAGE: Wage (dollars per hour)',
    'AGE: years',
    'RACE: 1=Other, 2=Hispanic, 3=White',
    'OCCUPATION: 1=Management, 2=Sales, 3=Clerical, 4=Service, 5=Professional, 6=Other',
    'SECTOR: 0=Other, 1=Manufacturing, 2=Construction',
    'MARR: 0=Unmarried,  1=Married',
]

# %%
print(data.columns)
# Out:
# Index(['EDUCATION', 'SOUTH', 'SEX', 'EXPERIENCE', 'UNION', 'WAGE', 'AGE',
#        'RACE', 'OCCUPATION', 'SECTOR', 'MARR'],
#       dtype='object')

# %%
result = smf.ols(formula='WAGE ~  + SEX + EDUCATION * SEX',
                data=data).fit()    
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   WAGE   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     43.72
# Date:                Mon, 17 Jul 2023   Prob (F-statistic):           2.94e-25
# Time:                        00:58:04   Log-Likelihood:                 88.503
# No. Observations:                 534   AIC:                            -169.0
# Df Residuals:                     530   BIC:                            -151.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.5748      0.058      9.861      0.000       0.460       0.689
# ...
